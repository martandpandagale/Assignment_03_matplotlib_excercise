# %% [markdown]
# # Assignment_03_matplotlib_excercise

# %%
import numpy as np
x=np.arange(0,100)
y=x*2
z=x**2

# %% [markdown]
# #### ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Exercise 1
# ** Follow along with these steps: **
#
# ** Create a figure object called fig using plt.figure() **
# ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig=plt.figure()
axis=fig.add_axes([0,0,1,1])
axis.plot(x,y,'r')
axis.set_xlabel('X axis')
axis.set_ylabel('Y axis')
axis.set_title('Title of graph')
# Out:
# Text(0.5, 1.0, 'Title of graph')

# %% [markdown]
# # Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# #### ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig=plt.figure()

ax1=fig.add_axes([0,0,1,1])
ax1.plot(x,y,'b')
ax1.set_xlabel('x axis1')
ax1.set_ylabel('y axis1')
ax1.set_title('Graph1')

ax2=fig.add_axes([0.2,0.5,0.2,0.2])
ax2.plot(x,y,'r')
ax2.set_xlabel('x axis2')
ax2.set_ylabel('y axis2')
ax2.set_title('Graph2')
# Out:
# Text(0.5, 1.0, 'Graph2')

# %% [markdown]
# #### ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig=plt.figure()

ax1=fig.add_axes([0,0,1,1])
ax1.plot(x,z,'b')
ax1.set_xlabel('x axis1')
ax1.set_ylabel('z axis1')
ax1.set_title('Graph1')

ax2=fig.add_axes([0.2,0.5,0.2,0.2])
ax2.plot(x,y,'r')
ax2.set_xlabel('x axis2')
ax2.set_ylabel('y axix2')
# Out:
# Text(0, 0.5, 'y axix2')

# %% [markdown]
# # Exercise 4
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
plt.subplots(nrows=1,ncols=2)
plt.show()

# %% [markdown]
# #### ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**
#
# ​

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for ax in axes:
    ax.plot(x,y,'r--')
    ax.set_xlabel('X axis label')
    ax.set_ylabel('Y axis label')
    ax.set_title('plat the graph')

# %%
fig,axis=plt.subplots(nrows=1,ncols=2)

axis[0].plot(x,y)

axis[1].plot(z,x,'r--')
plt.show()

# %% [markdown]
# #### ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.*

# %%
fig,axis=plt.subplots(1,2,figsize=(20,5))

axis[0].plot(x,y)

axis[1].plot(z,x,'r--')
plt.show()
